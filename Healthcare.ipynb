# %% [markdown]
# Importing the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Ignore warnings

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv('healthcare_dataset2.csv')
df
# Out:
#                Name  Age  Gender Blood Type Medical Condition  \
# 0     Bobby JacksOn   30    Male         B-            Cancer
# 1      LesLie TErRy   62    Male         A+           Obesity
# 2       DaNnY sMitH   76  Female         A-           Obesity
# 3      andrEw waTtS   28  Female         O+          Diabetes
# 4     adrIENNE bEll   43  Female        AB+            Cancer
# ...             ...  ...     ...        ...               ...
# 6927    jaCOB gaTeS   68  Female         O+         Arthritis
# 6928   cLAyton RYAn   67    Male         B+           Obesity
# 6929    reGINA wEbb   51    Male         O+           Obesity
# 6930  aRThUR PortER   42    Male        AB-      Hypertension
# 6931  dANiel bROokS   32  Female         A-            Cancer
#
#      Date of Admission             Doctor                    Hospital  \
# 0           2024-01-31      Matthew Smith             Sons and Miller
# 1           2019-08-20    Samantha Davies                     Kim Inc
# ...

# %%
#Viewing the first 5 rows
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
# Get the number of rows and columns in the DataFrame
df.shape
# Out:
# (6932, 15)

# %%
# Calculate the total number of missing values in each column of the DataFrame
missing_values = df.isnull().sum()
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           1
# Admission Type        1
# Discharge Date        1
# Medication            1
# Test Results          1
# dtype: int64

# %%
# Remove duplicate rows from the DataFrame, modifying the DataFrame in place
df.drop_duplicates(inplace=True)

# %%
# Generate summary statistics for numerical columns in the DataFrame
df.describe()
# Out:
#                Age  Billing Amount  Room Number
# count  6932.000000     6932.000000  6931.000000
# mean     51.898009    25617.393527   299.347280
# std      19.766480    14165.407943   115.485346
# min      18.000000    -1310.272895   101.000000
# 25%      35.000000    13350.827324   201.000000
# 50%      52.000000    25724.602718   302.000000
# 75%      69.000000    37739.926830   396.000000
# max      85.000000    52271.663747   500.000000

# %%
# Generate summary statistics for numerical columns and transpose the result for better readability
df.describe().T
# Out:
#                  count          mean           std          min           25%  \
# Age             6932.0     51.898009     19.766480    18.000000     35.000000
# Billing Amount  6932.0  25617.393527  14165.407943 -1310.272895  13350.827324
# Room Number     6931.0    299.347280    115.485346   101.000000    201.000000
#
#                          50%          75%           max
# Age                52.000000     69.00000     85.000000
# Billing Amount  25724.602718  37739.92683  52271.663747
# Room Number       302.000000    396.00000    500.000000

# %%
# Display a concise summary of the DataFrame, including the data types and non-null values of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6932 entries, 0 to 6931
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                6932 non-null   object
#  1   Age                 6932 non-null   int64
#  2   Gender              6932 non-null   object
#  3   Blood Type          6932 non-null   object
#  4   Medical Condition   6932 non-null   object
#  5   Date of Admission   6932 non-null   object
#  6   Doctor              6932 non-null   object
#  7   Hospital            6932 non-null   object
#  8   Insurance Provider  6932 non-null   object
#  9   Billing Amount      6932 non-null   float64
#  10  Room Number         6931 non-null   float64
#  11  Admission Type      6931 non-null   object
#  12  Discharge Date      6931 non-null   object
#  13  Medication          6931 non-null   object
#  14  Test Results        6931 non-null   object
# ...

# %% [markdown]
# **Datatype conversion**

# %%
# Convert the 'Discharge Date' column to datetime format
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# Convert the 'Date of Admission' column to datetime format
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6932 entries, 0 to 6931
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                6932 non-null   object
#  1   Age                 6932 non-null   int64
#  2   Gender              6932 non-null   object
#  3   Blood Type          6932 non-null   object
#  4   Medical Condition   6932 non-null   object
#  5   Date of Admission   6932 non-null   datetime64[ns]
#  6   Doctor              6932 non-null   object
#  7   Hospital            6932 non-null   object
#  8   Insurance Provider  6932 non-null   object
#  9   Billing Amount      6932 non-null   float64
#  10  Room Number         6931 non-null   float64
#  11  Admission Type      6931 non-null   object
#  12  Discharge Date      6931 non-null   datetime64[ns]
#  13  Medication          6931 non-null   object
#  14  Test Results        6931 non-null   object
# ...

# %%
# Display the first 5 rows of the DataFrame to get a quick overview of the data
print(df.head())
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %% [markdown]
# **EDA**

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each unique value in the 'Gender' column
# and plot these counts as a bar chart
df['Gender'].value_counts().plot(kind='bar')

# Add labels and title for clarity
plt.xlabel('Gender')  # Label for the x-axis
plt.ylabel('Count')   # Label for the y-axis
plt.title('Distribution of Gender')  # Title of the bar chart

# Show the plot
plt.show()

# %%
# Count the occurrences of each unique value in the 'Blood Type' column
# and plot these counts as a pie chart to visualize the distribution
df['Blood Type'].value_counts().plot(kind='pie', autopct='%1.1f%%')

# Add a title to the pie chart for clarity
plt.title('Distribution of Blood Types')

# Show the plot
plt.show()

# %%
df['Medical Condition'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Insurance Provider'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Admission Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Admission Type'>

# %%
df['Medication'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Medication'>

# %%
df['Test Results'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Test Results'>

# %% [markdown]
# **Importing Relevant Libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Distribution of numerical columns**

# %%
sns.distplot(df['Age'],kde=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15740\3467503581.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Billing Amount'],kde=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15740\297861269.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Billing Amount'],kde=True)
# <Axes: xlabel='Billing Amount', ylabel='Density'>

# %%
sns.countplot(x='Medical Condition', hue='Admission Type', data=df)
# Out:
# <Axes: xlabel='Medical Condition', ylabel='count'>

# %%
sns.boxplot(x='Gender', y='Age',hue='Medical Condition', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(x='Gender', y='Billing Amount',hue='Medical Condition', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Billing Amount'>

# %%
sns.countplot(x='Medical Condition', hue='Medication', data=df)
# Out:
# <Axes: xlabel='Medical Condition', ylabel='count'>

# %%
sns.boxplot(x='Insurance Provider', y='Billing Amount',hue='Medical Condition', data=df)
# Out:
# <Axes: xlabel='Insurance Provider', ylabel='Billing Amount'>

# %% [markdown]
# **Month with highest number of admissions**

# %%
df['Month']=df['Date of Admission'].dt.month_name()

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df['Month'].value_counts()
# Out:
# Month
# August       644
# March        614
# January      610
# May          604
# July         596
# October      593
# June         573
# December     558
# November     551
# April        538
# September    526
# February     525
# Name: count, dtype: int64

# %% [markdown]
# Number of days each patient were admitted for

# %%
df['admitted for']=(df['Discharge Date']-df['Date of Admission']).dt.days

# %%
df['admitted for'].value_counts()
# Out:
# admitted for
# 12.0    249
# 20.0    245
# 18.0    244
# 28.0    243
# 9.0     240
# 21.0    239
# 8.0     238
# 19.0    238
# 17.0    238
# 22.0    237
# 3.0     234
# 7.0     234
# 30.0    234
# 26.0    234
# 23.0    233
# 14.0    233
# 25.0    233
# 6.0     232
# 4.0     232
# 16.0    230
# 5.0     228
# 1.0     228
# 24.0    228
# 15.0    228
# 13.0    220
# 11.0    217
# 10.0    214
# 2.0     214
# 27.0    213
# 29.0    201
# Name: count, dtype: int64

# %%
sns.histplot(df['admitted for'], kde=True)
# Out:
# <Axes: xlabel='admitted for', ylabel='Count'>

# %%
l = list(df['admitted for'].unique())
chart = sns.countplot(x='admitted for', hue='Insurance Provider', data=df)

# Ensure the number of ticks and labels match
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '1.0'),
#  Text(1, 0, '2.0'),
#  Text(2, 0, '3.0'),
#  Text(3, 0, '4.0'),
#  Text(4, 0, '5.0'),
#  Text(5, 0, '6.0'),
#  Text(6, 0, '7.0'),
#  Text(7, 0, '8.0'),
#  Text(8, 0, '9.0'),
#  Text(9, 0, '10.0'),
#  Text(10, 0, '11.0'),
#  Text(11, 0, '12.0'),
#  Text(12, 0, '13.0'),
#  Text(13, 0, '14.0'),
#  Text(14, 0, '15.0'),
#  Text(15, 0, '16.0'),
#  Text(16, 0, '17.0'),
#  Text(17, 0, '18.0'),
#  Text(18, 0, '19.0'),
#  Text(19, 0, '20.0'),
#  Text(20, 0, '21.0'),
#  Text(21, 0, '22.0'),
#  Text(22, 0, '23.0'),
#  Text(23, 0, '24.0'),
#  Text(24, 0, '25.0'),
#  Text(25, 0, '26.0'),
#  Text(26, 0, '27.0'),
#  Text(27, 0, '28.0'),
#  Text(28, 0, '29.0'),
#  Text(29, 0, '30.0')]

# %%
sns.boxplot(x='Insurance Provider', y='admitted for',hue='Medical Condition', data=df)
# Out:
# <Axes: xlabel='Insurance Provider', ylabel='admitted for'>

# %%
sns.pairplot(df)
